# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/Salary_Stats_clean.csv")
df.head()
# Out:
#      Salary  Year          Player Pos  Age                Team  \
# 0   8800000  1978  Truck Robinson  PF   26    New Orleans Jazz
# 1  14800000  1978     Randy Smith  SG   29      Buffalo Braves
# 2  14700000  1978     Elvin Hayes  PF   32  Washington Bullets
# 3  20600000  1978     Dave Cowens   C   29      Boston Celtics
# 4  18500000  1978      Bob McAdoo   C   26     New York Knicks
#
#    Championship Wins  RunnerUp Count     TRB  AST  ...    BLK    TOV   PF  \
# 0                0.0             1.0  1288.0  171  ...   79.0  301.0  265
# 1                0.0             0.0   310.0  458  ...   11.0  286.0  224
# 2                1.0             2.0  1075.0  149  ...  159.0  229.0  313
# 3                2.0             0.0  1078.0  351  ...   67.0  217.0  297
# 4                2.0             2.0  1010.0  298  ...  126.0  346.0  297
#
#     PER    FG%  3P%  FTA    FT%   PTS  Championship Appearance Y/N
# 0  15.7  0.444  0.0  572  0.640  1862                          1.0
# 1  19.1  0.465  0.0  554  0.800  2021                          0.0
# 2  17.1  0.451  0.0  514  0.634  1598                          1.0
# 3  18.6  0.490  0.0  284  0.842  1435                          1.0
# 4  22.0  0.520  0.0  645  0.727  2097                          1.0
#
# [5 rows x 21 columns]

# %%
filtered_df = df[["PTS", "TRB", "AST", "Salary"]]
filtered_df
# Out:
#         PTS     TRB  AST    Salary
# 0      1862  1288.0  171   8800000
# 1      2021   310.0  458  14800000
# 2      1598  1075.0  149  14700000
# 3      1435  1078.0  351  20600000
# 4      2097  1010.0  298  18500000
# ...     ...     ...  ...       ...
# 13800    34    19.0   43    700000
# 13801    23     9.0   17    700000
# 13802    18     8.0    5    900000
# 13803     5     3.0    2    900000
# 13804    25     3.0    6    900000
#
# [13805 rows x 4 columns]

# %%
X = np.array(filtered_df[["PTS", "TRB", "AST"]])
y = np.array(filtered_df["Salary"])
print(X.shape)
# print(y.shape)
# Out:
# (13805, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(5, 5))
axes = Axes3D(fig, elev=20, azim=45)
axes.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap=plt.cm.get_cmap("Spectral"))
plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.5858234499104074

# %% [markdown]
# ## Model with Unique Player and Salary Records
# * Only keep performance and salary information from the last season played
# * Assumptions:
#     * Player performance is at its peak during their final season
#     * Players are earning their highest salaries during their final season

# %%
final_salary_df = pd.read_csv("data/Unique_Salary_clean.csv")
final_salary_df.head()
# Out:
#     Salary  Year          Player Pos  Age                   Team  \
# 0  6800000  1978   John Havlicek  SF   37         Boston Celtics
# 1  2900000  1978       Dave Bing  PG   34         Boston Celtics
# 2   800000  1978  Chuck Williams  PG   31         Buffalo Braves
# 3  6100000  1978     Butch Beard  PG   30        New York Knicks
# 4  4000000  1978    E.C. Coleman  PF   27  Golden State Warriors
#
#    Championship Wins  RunnerUp Count    TRB  AST  ...   BLK    TOV   PF   PER  \
# 0                8.0             0.0  332.0  328  ...  22.0  204.0  185  14.3
# 1                0.0             0.0  212.0  300  ...  18.0  216.0  247  13.4
# 2                0.0             0.0  137.0  317  ...   4.0  156.0  137   9.5
# 3                1.0             0.0  264.0  339  ...   3.0  154.0  201  14.6
# 4                0.0             0.0  376.0  100  ...  23.0   95.0  253   9.1
#
#      FG%  3P%  FTA    FT%   PTS  Championship Appearance Y/N
# 0  0.449  0.0  269  0.855  1322                          1.0
# 1  0.449  0.0  296  0.824  1088                          0.0
# 2  0.477  0.0  138  0.826   530                          0.0
# 3  0.502  0.0  160  0.806   745                          1.0
# 4  0.475  0.0   55  0.727   464                          0.0
#
# [5 rows x 21 columns]

# %%
filtered_final_df = final_salary_df[["PTS", "TRB", "AST", "Salary"]]
filtered_final_df
# Out:
#        PTS    TRB  AST   Salary
# 0     1322  332.0  328  6800000
# 1     1088  212.0  300  2900000
# 2      530  137.0  317   800000
# 3      745  264.0  339  6100000
# 4      464  376.0  100  4000000
# ...    ...    ...  ...      ...
# 1888    26   14.0    8   600000
# 1889    20   17.0    6   700000
# 1890    23    9.0   17   700000
# 1891    18    8.0    5   900000
# 1892    25    3.0    6   900000
#
# [1893 rows x 4 columns]

# %%
X = np.array(filtered_final_df[["PTS", "TRB", "AST"]])
y = np.array(filtered_final_df["Salary"])
print(X.shape)
# print(y.shape)
# Out:
# (1893, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(5, 5))
axes = Axes3D(fig, elev=20, azim=45)
axes.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap=plt.cm.get_cmap("Spectral"))
plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.4618263513893426

# %% [markdown]
# ## Average Salary and Performance

# %%
avg_salary_df = pd.read_csv("data/Average_Salary_clean.csv")
avg_salary_df.head()
# Out:
#          Salary         Year        Age  Championship Wins  RunnerUp Count  \
# 0  7.157895e+06  1994.052632  30.052632                3.0             2.0
# 1  1.000000e+06  1991.000000  23.000000                0.0             0.0
# 2  8.857143e+05  2013.000000  26.000000                0.0             1.0
# 3  2.192857e+06  2012.000000  27.000000                0.0             0.0
# 4  7.000000e+05  2015.000000  19.000000                0.0             0.0
#
#           TRB         AST        STL        BLK         TOV          PF  \
# 0  533.105263   77.315789  58.052632  29.578947   79.368421  135.842105
# 1  147.000000  177.000000  25.000000  15.000000  114.000000  127.000000
# 2   52.428571   79.142857  17.714286   1.285714   31.714286   33.142857
# 3   79.285714  147.571429  27.428571   6.000000   75.500000   87.500000
# 4  169.000000   33.000000  21.000000  22.000000   38.000000   83.000000
#
#          PER       FG%       3P%         FTA       FT%         PTS  \
# 0  13.763158  0.487263  0.139579  234.052632  0.704842  680.421053
# 1  10.600000  0.439000  0.097000  157.000000  0.707000  616.000000
# 2  10.257143  0.344571  0.235714   39.571429  0.627286  211.285714
# 3  12.735714  0.399357  0.350786   86.785714  0.794786  475.000000
# 4  11.400000  0.447000  0.271000   61.000000  0.721000  243.000000
#
#    Championship Appearance Y/N
# 0                          1.0
# 1                          0.0
# 2                          1.0
# 3                          0.0
# 4                          0.0

# %%
filtered_avg_df = avg_salary_df[["PTS", "TRB", "AST", "Salary"]]
filtered_avg_df
# Out:
#              PTS         TRB         AST        Salary
# 0     680.421053  533.105263   77.315789  7.157895e+06
# 1     616.000000  147.000000  177.000000  1.000000e+06
# 2     211.285714   52.428571   79.142857  8.857143e+05
# 3     475.000000   79.285714  147.571429  2.192857e+06
# 4     243.000000  169.000000   33.000000  7.000000e+05
# ...          ...         ...         ...           ...
# 1888  518.200000  417.900000   92.400000  3.660000e+06
# 1889  212.666667  114.666667   14.666667  7.833333e+05
# 1890  169.000000  146.000000   13.000000  9.000000e+05
# 1891  217.000000   69.000000   44.000000  7.000000e+05
# 1892  844.307692  476.230769   73.461538  5.953846e+06
#
# [1893 rows x 4 columns]

# %%
X = np.array(filtered_avg_df[["PTS", "TRB", "AST"]])
y = np.array(filtered_avg_df["Salary"])
print(X.shape)
# print(y.shape)
# Out:
# (1893, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(5, 5))
axes = Axes3D(fig, elev=20, azim=45)
axes.scatter(X[:,0], X[:,1], X[:,2], c=y, cmap=plt.cm.get_cmap("Spectral"))
plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.6602151004965571
